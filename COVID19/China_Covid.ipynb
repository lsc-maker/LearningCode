# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt

# %%
CN_data = pd.read_excel('分日病例汇总.xlsx', sheet_name = '全国')

# %%
CN_data.head()
# Out:
#           日期  新增确诊  境外新增  新增重症  新增死亡    新增疑似  累计确诊  境外累计   累计重症  累计死亡    累计疑似  \
# 0 2020-01-20    77   NaN   NaN   NaN     NaN   291   NaN    NaN   NaN     NaN
# 1 2020-01-21   149   NaN   NaN   3.0     NaN   440   NaN  102.0   9.0     NaN
# 2 2020-01-22   131   NaN   NaN   8.0   257.0   571   NaN   95.0  17.0   393.0
# 3 2020-01-23   259   NaN   NaN   8.0   680.0   830   NaN  177.0  25.0  1072.0
# 4 2020-01-24   444   NaN   NaN  16.0  1118.0  1287   NaN  237.0  41.0  1965.0
#
#    累计医学观察  当日解除医学观察  现有医学观察  当日新增无症状  当日确诊无症状  当日解除无症状  现存无症状
# 0    1739       817     922      NaN      NaN      NaN    NaN
# 1    2197       765    1394      NaN      NaN      NaN    NaN
# 2    5897       969    4928      NaN      NaN      NaN    NaN
# 3    9507      1087    8420      NaN      NaN      NaN    NaN
# 4   15297      1230   13967      NaN      NaN      NaN    NaN

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'svg'

CN_data.plot(x = "日期",y = ["新增确诊","新增重症","新增死亡","新增疑似"],figsize=(10,6))
plt.xticks(rotation=90)
# Out:
# (array([18281, 18293, 18322, 18353, 18365], dtype=int64),
#  <a list of 5 Text xticklabel objects>)
